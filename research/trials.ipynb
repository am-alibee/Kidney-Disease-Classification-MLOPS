# %%
from  box import ConfigBox
from ensure import ensure_annotations

# %%
d = {"key": "value", "key1": "value1", "key2": "value2"}

# %%
config_dict = ConfigBox(d)
config_dict
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1', 'key2': 'value2'})

# %%
config_dict.key
# Out:
# 'value'

# %%
type(config_dict)
# Out:
# box.config_box.ConfigBox

# %%
@ensure_annotations
def predict(x: int, y: int) -> int:
    return x * y

# %%
predict(4, "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 predict(4, "3")
#
# File c:\Users\hp\miniconda3\envs\chest_cancer_mlops_py310\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function predict at 0x0000023CC1099A20> does not match annotation type <class 'int'>

# %%
predict(2, 6)
# Out:
# 12

# %%
from cnnClassifier.utils.common import read_yaml

# %%
read_yaml("../sdfsdfl/sdlfsdfkj.yaml")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 read_yaml("../sdfsdfl/sdlfsdfkj.yaml")
#
# File c:\Users\hp\miniconda3\envs\chest_cancer_mlops_py310\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# ...
